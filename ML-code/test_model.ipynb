# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('train_model1.keras')

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
image_path = "df3.jpg"
##read imp
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#img = img/255

##display
plt.imshow(img)
plt.title("Test Img")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(96,96))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
input_arr = input_arr/255
input_arr = tf.cast(input_arr, tf.float32)
print(input_arr.shape)
# Out:
# (1, 96, 96, 3)

# %%
prediction = model.predict(input_arr)
prediction,prediction.shape
# Out:
# 1/1 [==============================] - 0s 6ms/step
# (array([[6.7839466e-07, 7.6850092e-06, 1.1141715e-05, 9.1240907e-01,
#          2.5970978e-04, 8.7311544e-02, 1.4419578e-07]], dtype=float32),
#  (1, 7))

# %%
result_index = np.argmax(prediction)
result_index
# Out:
# 3

# %%
class_name = ['Actinic keratoses and intraepithelial carcinoma','Basal cell carcinoma','Benign keratosis-like lesions',
              'Dermatofibroma','Melanoma','Melanocytic nevi','Vascular lesions']

# %%
model_prediction = class_name[result_index]
print(model_prediction)
# Out:
# Dermatofibroma
